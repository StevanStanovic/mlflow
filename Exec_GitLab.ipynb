# %%
import mlflow
from mlflow import projects
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
mlflow.set_tracking_uri("databricks")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
be_config="/dbfs/FileStore/tables/cluster2.json"
ml_project_uri = "https://gitlab.com/stevan.stanovic/mlflow"
exp_id = 3103852906971320
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
params = {"nb_batch" : 64, "nb_epochs" : 50}

#exp = mlflow.run(ml_project_uri, experiment_id=exp_id)
exp = projects.run(ml_project_uri,experiment_id=exp_id, backend='databricks', backend_config=be_config, entry_point="ann", parameters=params)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
params = {"criterion" : "entropy"}

exp2 = projects.run(ml_project_uri,experiment_id=exp_id, backend='databricks', backend_config=be_config, entry_point="decisionTree", parameters=params)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
exp3 = projects.run(ml_project_uri,experiment_id=exp_id, backend='databricks', backend_config=be_config, entry_point="gaussianNaiveBayes")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
params = {"nb_neighbors" : 2, "metrics" : "minkowski", "p" : 2}

exp4 = projects.run(ml_project_uri,experiment_id=exp_id, backend='databricks', backend_config=be_config, entry_point="knn", parameters=params)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
params = {"nb_estim" : 20, "criterion" : "entropy"}

exp5 = projects.run(ml_project_uri,experiment_id=exp_id, backend='databricks', backend_config=be_config, entry_point="randomForest", parameters=params)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
exp6 = projects.run(ml_project_uri,experiment_id=exp_id, backend='databricks', backend_config=be_config, entry_point="regressionLogistique")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
params = {"C" : 0.9, "kernel" : "rbf"}

exp7 = projects.run(ml_project_uri,experiment_id=exp_id, backend='databricks', backend_config=be_config, entry_point="SVMGauss", parameters=params)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import numpy as np
import pandas as pd
import mlflow.pyfunc
import mlflow.keras
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# CreditScore Geography Gender Age Tenure Balance NumOfProducts HasCrCard IsActiveMember EstimatedSalary
# [619,'Spain','Female',39,2,113756,2,1,1,71725.7]
# [712,'Germany','Male',31,8,0,5,0,0,62232.6]
#
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
X_pyfunc=pd.DataFrame(np.array([[-1.00280393,-0.57873591,1.74273971,-0.32622142,-1.09598752,0.00745665,-1.04175968,0.59733212,0.80773656,0.64609167,0.97024255,-0.49323101],[-1.00280393,1.72790383,-0.57380915,0.63602872,0.91241915,-0.75537207,1.03290776,-1.22584767,5.96569673,-1.54776799,-1.03067011,-0.65830653]]))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
pyfunc_uri = "runs:/{}/model".format('b4aecc96af5a428c8b4dd919e9631f12')
# pyfunc_uri = "/dbfs/databricks/mlflow/3103852906971320/b4aecc96af5a428c8b4dd919e9631f12/artifacts/model"
pyfunc_model = mlflow.keras.load_model(pyfunc_uri)
pred = pyfunc_model.predict(X_pyfunc.values)
print(pred)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">WARNING:tensorflow:Sequential models without an `input_shape` passed to the first layer cannot reload their optimizer state. As a result, your model isstarting with a freshly initialized optimizer.
# WARNING:tensorflow:From /databricks/python/lib/python3.7/site-packages/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# [[0.15491109]
#  [0.9998323 ]]
# </div>

# %%
pyfunc_uri = "runs:/{}/{}".format('0edd065a2e3c42a3a1c9b1c56044184b','Decision Tree_Modele')
# pyfunc_uri = "/dbfs/databricks/mlflow/3103852906971320/0edd065a2e3c42a3a1c9b1c56044184b/artifacts/Decision Tree_Modele"
pyfunc_model = mlflow.pyfunc.load_model(pyfunc_uri)
pred = pyfunc_model.predict(X_pyfunc)
print(pred)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[0 0]
# </div>

# %%
pyfunc_uri = "/dbfs/databricks/mlflow/3103852906971320/dc5937abba354212a07ddd02f4287d67/artifacts/Gaussian Naive Bayes_Modele"
pyfunc_model = mlflow.pyfunc.load_model(pyfunc_uri)
pred = pyfunc_model.predict(X_pyfunc)
print(pred)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[0 1]
# </div>

# %%
pyfunc_uri = "/dbfs/databricks/mlflow/3103852906971320/f91ad00df156407a858ef2eb7f820ce2/artifacts/KNN_Modele"
pyfunc_model = mlflow.pyfunc.load_model(pyfunc_uri)
pred = pyfunc_model.predict(X_pyfunc)
print(pred)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[0 1]
# </div>

# %%
pyfunc_uri = "/dbfs/databricks/mlflow/3103852906971320/211f1fd289324eeb831ce834a3de4f66/artifacts/Random Forest_Modele"
pyfunc_model = mlflow.pyfunc.load_model(pyfunc_uri)
pred = pyfunc_model.predict(X_pyfunc)
print(pred)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[0 1]
# </div>

# %%
pyfunc_uri = "/dbfs/databricks/mlflow/3103852906971320/1f29359ad0b84a9a975f75e9b1ebc405/artifacts/Regression Logistique_Modele"
pyfunc_model = mlflow.pyfunc.load_model(pyfunc_uri)
pred = pyfunc_model.predict(X_pyfunc)
print(pred)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[0 0]
# </div>

# %%
pyfunc_uri = "/dbfs/databricks/mlflow/3103852906971320/2357087139c14b5788aaeb2d74a4668d/artifacts/SVM Gauss_Modele"
pyfunc_model = mlflow.pyfunc.load_model(pyfunc_uri)
pred = pyfunc_model.predict(X_pyfunc)
print(pred)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[0 1]
# </div>
